# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
data = pd.read_csv("C:\\Users\\niraj\\Desktop\\dataset\\1.tab", sep ='\t')

# %%
df = pd.DataFrame(data)
df
# Out:
#        Event ID  Event Date  \
# 0      37530852  2023-01-01
# 1      37530790  2023-01-01
# 2      37530846  2023-01-01
# 3      37530848  2023-01-01
# 4      37530847  2023-01-01
# ...         ...         ...
# 3150   37533802  2023-01-03
# 3151   37532924  2023-01-03
# 3152   37533049  2023-01-03
# 3153   37532925  2023-01-03
# 3154   37533225  2023-01-03
#
#                                             Source Name  \
# 0             Defense / Security Ministry (South Korea)
# 1                 Defense / Security Ministry (Ukraine)
# 2                  Defense / Security Ministry (Russia)
# 3                                     Military (Russia)
# 4                                               Ukraine
# ...                                                 ...
# 3150                                               Iran
# 3151                                              India
# 3152  Cabinet / Council of Ministers / Advisors (India)
# ...

# %%
data_1 = data[data["Source Country"]=='Nepal'][["Event Date","Source Name","Event Text","Target Sectors","Province","Target Name"]]
data_1
# Out:
#       Event Date          Source Name                        Event Text  \
# 1293  2023-01-02  Bahujan Samaj Party                 Praise or endorse
# 1561  2023-01-02            Prachanda         Make an appeal or request
# 2961  2023-01-03                Nepal  Engage in diplomatic cooperation
# 2999  2023-01-03  Bahujan Samaj Party                 Praise or endorse
# 3013  2023-01-03  Bahujan Samaj Party                 Praise or endorse
# 3019  2023-01-03  Bahujan Samaj Party                 Praise or endorse
# 3021  2023-01-03  Bahujan Samaj Party                 Praise or endorse
#
#                               Target Sectors                Province  \
# 1293  Government,Legislative / Parliamentary  State of Uttar Pradesh
# 1561                                     NaN              Purwanchal
# 2961                                     NaN          Pashchimanchal
# 2999  Government,Legislative / Parliamentary  State of Uttar Pradesh
# ...

# %%
data_1 = data[data["Event Date"]=='2023-01-01'][["Event Date","Source Name","Event Text","Target Sectors","Province","Target Name"]]
data_1
# Out:
#      Event Date                                Source Name  \
# 0    2023-01-01  Defense / Security Ministry (South Korea)
# 1    2023-01-01      Defense / Security Ministry (Ukraine)
# 2    2023-01-01       Defense / Security Ministry (Russia)
# 3    2023-01-01                          Military (Russia)
# 4    2023-01-01                                    Ukraine
# ..          ...                                        ...
# 731  2023-01-01                                     Russia
# 732  2023-01-01                              United States
# 733  2023-01-01                            Emmanuel Macron
# 734  2023-01-01                Head of Government (France)
# 735  2023-01-01       Defense / Security Ministry (France)
#
#                                   Event Text  \
# 0                             Make statement
# 1                             Make statement
# 2                             Make statement
# 3    fight with small arms and light weapons
# ...
